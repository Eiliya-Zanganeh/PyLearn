# %% [markdown]
# # 1. Import dependents

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from perceptron import Perceptron

# %% [markdown]
# # 2. Load data and preprocessing data

# %%
df = pd.read_csv('abalone.csv')
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.loc[df['Sex'] == 'M', 'Sex'] = 0
df.loc[df['Sex'] == 'F', 'Sex'] = 1
df.loc[df['Sex'] == 'I', 'Sex'] = 2

# %%
corr_matrix = df.corr()
plt.imshow(corr_matrix.to_numpy(), cmap='coolwarm', interpolation='nearest') 
plt.colorbar()

plt.xticks(ticks=range(len(corr_matrix.columns)), labels=corr_matrix.columns, rotation=90)
plt.yticks(ticks=range(len(corr_matrix.columns)), labels=corr_matrix.columns)

plt.show()

# %%
X = df['Diameter'].values
Y = df['Length'].values

# %%
plt.scatter(X, Y)
plt.show()

# %% [markdown]
# # 3. Train, Test split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=42)

# %% [markdown]
# # 4. Initial model

# %%
model = Perceptron(
    weight_learning_rate=.001,
    bias_learning_rate=.001,
    epochs=80
)

# %% [markdown]
# # 5. Train model

# %%
model.train(x_train, y_train)
# Out:
# Epoch: 1, Loss: 0.08001059606435262
# Epoch: 2, Loss: 0.07758435780683531
# Epoch: 3, Loss: 0.07553994849098745
# Epoch: 4, Loss: 0.07354032053812652
# Epoch: 5, Loss: 0.07159727085046144
# Epoch: 6, Loss: 0.06970975380076795
# Epoch: 7, Loss: 0.06787661490772368
# Epoch: 8, Loss: 0.06609631898199818
# Epoch: 9, Loss: 0.06436715852593586
# Epoch: 10, Loss: 0.06268886054745174
# Epoch: 11, Loss: 0.061058474487576835
# Epoch: 12, Loss: 0.059474310799536
# Epoch: 13, Loss: 0.057935573091472396
# Epoch: 14, Loss: 0.056442551400246836
# Epoch: 15, Loss: 0.05499197121790571
# Epoch: 16, Loss: 0.05358357234393921
# Epoch: 17, Loss: 0.052217106056747245
# Epoch: 18, Loss: 0.05089032376906684
# Epoch: 19, Loss: 0.04960270116649726
# Epoch: 20, Loss: 0.04835306995958794
# Epoch: 21, Loss: 0.04714138260231115
# Epoch: 22, Loss: 0.04596584572404391
# Epoch: 23, Loss: 0.04482582228771264
# Epoch: 24, Loss: 0.043719867325632454
# Epoch: 25, Loss: 0.04264883818636162
# Epoch: 26, Loss: 0.041609603550566567
# Epoch: 27, Loss: 0.04060161317392599
# Epoch: 28, Loss: 0.03962676260774454
# Epoch: 29, Loss: 0.0386828704955488
# Epoch: 30, Loss: 0.037767740735264274
# Epoch: 31, Loss: 0.036881743213525116
# Epoch: 32, Loss: 0.036023059773311446
# Epoch: 33, Loss: 0.03519217261367284
# Epoch: 34, Loss: 0.03438872600307869
# Epoch: 35, Loss: 0.033612636535802466
# Epoch: 36, Loss: 0.03286088963327438
# Epoch: 37, Loss: 0.03213274745314551
# Epoch: 38, Loss: 0.0314288207461751
# Epoch: 39, Loss: 0.030749195939458827
# Epoch: 40, Loss: 0.030093606492829567
# Epoch: 41, Loss: 0.029462682149779137
# Epoch: 42, Loss: 0.02885354835433266
# Epoch: 43, Loss: 0.028264448885727645
# Epoch: 44, Loss: 0.027695475494923568
# Epoch: 45, Loss: 0.02714470648513108
# Epoch: 46, Loss: 0.026613822314291255
# Epoch: 47, Loss: 0.026103577808762796
# Epoch: 48, Loss: 0.02560984204391604
# Epoch: 49, Loss: 0.025135089042669773
# Epoch: 50, Loss: 0.02467813331626984
# Epoch: 51, Loss: 0.024238186249910268
# Epoch: 52, Loss: 0.023815093030259804
# Epoch: 53, Loss: 0.0234079156880949
# Epoch: 54, Loss: 0.023016459880597608
# Epoch: 55, Loss: 0.022641837906597653
# Epoch: 56, Loss: 0.022283394576790672
# Epoch: 57, Loss: 0.02194086392806342
# Epoch: 58, Loss: 0.021612335303954025
# Epoch: 59, Loss: 0.02129351650148608
# Epoch: 60, Loss: 0.020983454161987457
# Epoch: 61, Loss: 0.02068190778633061
# Epoch: 62, Loss: 0.02038971503623762
# Epoch: 63, Loss: 0.020108690528946593
# Epoch: 64, Loss: 0.019836669950424324
# Epoch: 65, Loss: 0.01957663898739442
# Epoch: 66, Loss: 0.01932846048933057
# Epoch: 67, Loss: 0.01909239224672735
# Epoch: 68, Loss: 0.01886752527447453
# Epoch: 69, Loss: 0.01865159539940404
# Epoch: 70, Loss: 0.018443769919373933
# Epoch: 71, Loss: 0.01824480592080201
# Epoch: 72, Loss: 0.018054844671704463
# Epoch: 73, Loss: 0.01787305456398123
# Epoch: 74, Loss: 0.01770004234019006
# Epoch: 75, Loss: 0.017534699454731104
# Epoch: 76, Loss: 0.017377923040820288
# Epoch: 77, Loss: 0.017228805754313917
# Epoch: 78, Loss: 0.017086643273802472
# Epoch: 79, Loss: 0.01694982829847486
# Epoch: 80, Loss: 0.016818137337675537

# %% [markdown]
# # 6. Evaluate model

# %%
x_test = x_test.reshape(-1, 1)
model.evaluate(x_test, y_test)
# Out:
# 0.13011367443220143

# %%
y_pred = model.predict(x_test)
y_pred.shape
# Out:
# (836, 1)

# %%
y_pred = y_pred.reshape(-1)
y_pred.shape
# Out:
# (836,)

# %%
fig, (ax_1, ax_2) = plt.subplots(1, 2, figsize=(15, 5))
ax_1.scatter(x_test, y_test, color='blue')
ax_1.plot(x_test, y_pred, color='red')
ax_1.set_title("Predict Test Data")
ax_1.set_xlabel("X")
ax_1.set_ylabel("Y")

ax_2.plot(model.losses)
ax_2.set_title("Loss")
ax_2.set_xlabel("Epochs")
ax_2.set_ylabel("loss")
plt.show()
