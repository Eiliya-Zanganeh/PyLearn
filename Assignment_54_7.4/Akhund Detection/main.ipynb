# %%
from train import train, test

# %%
train()
# Out:
# Epoch [1/10]
# Train Loss:  0.6289 | Train Accuracy:  0.7498
# Validation Loss: 0.6031 | Validation Accuracy: 0.8261
# Epoch [2/10]
# Train Loss:  0.5195 | Train Accuracy:  0.8826
# Validation Loss: 0.5145 | Validation Accuracy: 0.8261
# Epoch [3/10]
# Train Loss:  0.4503 | Train Accuracy:  0.8645
# Validation Loss: 0.4588 | Validation Accuracy: 0.8261
# Epoch [4/10]
# Train Loss:  0.3981 | Train Accuracy:  0.9191
# Validation Loss: 0.4242 | Validation Accuracy: 0.8261
# Epoch [5/10]
# Train Loss:  0.3592 | Train Accuracy:  0.9139
# Validation Loss: 0.3927 | Validation Accuracy: 0.8261
# Epoch [6/10]
# Train Loss:  0.3248 | Train Accuracy:  0.9334
# Validation Loss: 0.3777 | Validation Accuracy: 0.8261
# Epoch [7/10]
# Train Loss:  0.3195 | Train Accuracy:  0.9165
# Validation Loss: 0.3570 | Validation Accuracy: 0.8261
# Epoch [8/10]
# Train Loss:  0.2884 | Train Accuracy:  0.9296
# Validation Loss: 0.3431 | Validation Accuracy: 0.8261
# Epoch [9/10]
# ...

# %%
test()
# Out:
# Test Loss: 0.2481, Test Accuracy: 93.75%
